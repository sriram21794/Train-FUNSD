# %%
from matplotlib import pyplot as plt
# %matplotlib notebook
import glob
import os
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import os
from IPython.display import Image
import json

# %%
DATASTE_FOLDER="/Users/user421/datasets/FUNSD/dataset/"

train = os.path.join(DATASTE_FOLDER, "training_data")
test = os.path.join(DATASTE_FOLDER, "testing_data")

train_images = sorted(glob.glob("{}/images/*".format(train)))
test_images = sorted(glob.glob("{}/images/*".format(test)))

train_annotations = sorted(glob.glob("{}/annotations/*".format(train)))
test_annotations = sorted(glob.glob("{}/annotations/*".format(test)))

print("Total Train images={}. Total Train annotations={}.".format(len(train_images), len(train_annotations)))
print("Total Test images={}. Total Test annotations={}.".format(len(test_images), len(test_annotations)))
# Out:
# Total Train images=149. Total Train annotations=149.
# Total Test images=50. Total Test annotations=50.

# %%
class Constants:
    RED = [255,0,0]
    GREEN = [0,255, 0]
    BLUE = [0,0,255]
    CYAN = [0, 255, 255]
    
    
class Box():
    def __init__(self, xmin, ymin, xmax, ymax):
        self.xmin, self.ymin, self.xmax, self.ymax = xmin, ymin, xmax, ymax
    
    def __gt__(self, rhs):
        return (self.ymin, self.xmin, self.ymax, self.xmax) > (rhs.ymin, rhs.xmin, rhs.ymax, rhs.xmax)
    
    def __repr__(self):
        return f"Box(xmin={self.xmin},ymin={self.ymin}, xmax={self.xmax}, ymax={self.ymax})"

class Word:
    def __init__(self, box, text):
        self.box = Box(*box)
        self.text = text
        
    def __getitem__(self, item):
        if not hasattr(self, item):
            raise KeyError(f"{item} is not present in {self.__class__}")
        return getattr(self, item)
    
    def __repr__(self):
        return f"Word(box={self.box}, text={self.text})"
        
    
class Entity:
    def __init__(self, id_, box, text, label, words, linking):
        self.id_ = id_
        self.box = Box(*box)
        self.text = text
        self.label = label
        self.words = [ Word(**word) for word in words ] 
        self.linking = linking
    
    def __getitem__(self, item):
        if not hasattr(self, item):
            raise KeyError(f"{item} is not present in {self.__class__}")
        return getattr(self, item)
    
    def __repr__(self):
        return f"Entity(id_={self.id_}, box={self.box}, text={self.text}, label={self.label}, words={self.words}, linking={self.linking})"
    
class Form():
    def __init__(self, entities):
        self.entities = [Entity(id_=idx, **entity) for idx, entity in enumerate(entities)]
        
    def __repr__(self):
        return f"Form(entities={self.entities})"

# %%
train_image_file_names = [image_file.rsplit(os.sep,1)[-1] for image_file in train_images ]
train_images_dir = train_images[0].rsplit(os.sep,1)[0]

annotations = []
for train_annotation in train_annotations:
    with open(train_annotation) as fp:
        annotations.append(Form(json.loads(fp.read())["form"]))

# %%
words_list = [ [word for enitity in annotation.entities for word in enitity.words] for annotation in annotations ]

# %%
features = []
all_words = sorted(words_list[0], key=lambda w_: w_.box)
for word in all_words:
    x1, y1, x2, y2 = word.box.xmin, word.box.ymin, word.box.xmax, word.box.ymax
    x, y, w, h = (x1 + x2) / 2, (y1 + y2) / 2, (x2 - x1), (y2 - y1)
    features.append([x, y])

# %%
from sklearn.cluster.k_means_ import check_random_state, check_array, _check_sample_weight, row_norms, _tolerance
class KmeansClustering(KMeans):
    
    def __init__(self, *args, **kwargs):
        super(KmeansClustering, self).__init__(*args, **kwargs)
    
    def fit(self, X, y=None, sample_weight=None):
            """Compute the centroids on X by chunking it into mini-batches.

            Parameters
            ----------
            X : array-like or sparse matrix, shape=(n_samples, n_features)
                Training instances to cluster. It must be noted that the data
                will be converted to C ordering, which will cause a memory copy
                if the given data is not C-contiguous.

            y : Ignored
                not used, present here for API consistency by convention.

            sample_weight : array-like, shape (n_samples,), optional
                The weights for each observation in X. If None, all observations
                are assigned equal weight (default: None)

            """
            random_state = check_random_state(self.random_state)
            X = check_array(X, accept_sparse="csr", order='C',
                            dtype=[np.float64, np.float32])
            n_samples, n_features = X.shape
            if n_samples < self.n_clusters:
                raise ValueError("n_samples=%d should be >= n_clusters=%d"
                                 % (n_samples, self.n_clusters))

            sample_weight = _check_sample_weight(X, sample_weight)

            n_init = self.n_init
            if hasattr(self.init, '__array__'):
                self.init = np.ascontiguousarray(self.init, dtype=X.dtype)
                if n_init != 1:
                    warnings.warn(
                        'Explicit initial center position passed: '
                        'performing only one init in MiniBatchKMeans instead of '
                        'n_init=%d'
                        % self.n_init, RuntimeWarning, stacklevel=2)
                    n_init = 1

            x_squared_norms = row_norms(X, squared=True)

            if self.tol > 0.0:
                tol = _tolerance(X, self.tol)

                # using tol-based early stopping needs the allocation of a
                # dedicated before which can be expensive for high dim data:
                # hence we allocate it outside of the main loop
                old_center_buffer = np.zeros(n_features, dtype=X.dtype)
            else:
                tol = 0.0
                # no need for the center buffer if tol-based early stopping is
                # disabled
                old_center_buffer = np.zeros(0, dtype=X.dtype)

            distances = np.zeros(self.batch_size, dtype=X.dtype)
            n_batches = int(np.ceil(float(n_samples) / self.batch_size))
            n_iter = int(self.max_iter * n_batches)

            init_size = self.init_size
            if init_size is None:
                init_size = 3 * self.batch_size
            if init_size > n_samples:
                init_size = n_samples
            self.init_size_ = init_size

            validation_indices = random_state.randint(0, n_samples, init_size)
            X_valid = X[validation_indices]
            sample_weight_valid = sample_weight[validation_indices]
            x_squared_norms_valid = x_squared_norms[validation_indices]

            # perform several inits with random sub-sets
            best_inertia = None
            for init_idx in range(n_init):
                if self.verbose:
                    print("Init %d/%d with method: %s"
                          % (init_idx + 1, n_init, self.init))
                weight_sums = np.zeros(self.n_clusters, dtype=sample_weight.dtype)

                # TODO: once the `k_means` function works with sparse input we
                # should refactor the following init to use it instead.

                # Initialize the centers using only a fraction of the data as we
                # expect n_samples to be very large when using MiniBatchKMeans
                cluster_centers = _init_centroids(
                    X, self.n_clusters, self.init,
                    random_state=random_state,
                    x_squared_norms=x_squared_norms,
                    init_size=init_size)

                # Compute the label assignment on the init dataset
                _mini_batch_step(
                    X_valid, sample_weight_valid,
                    x_squared_norms[validation_indices], cluster_centers,
                    weight_sums, old_center_buffer, False, distances=None,
                    verbose=self.verbose)

                # Keep only the best cluster centers across independent inits on
                # the common validation set
                _, inertia = _labels_inertia(X_valid, sample_weight_valid,
                                             x_squared_norms_valid,
                                             cluster_centers)
                if self.verbose:
                    print("Inertia for init %d/%d: %f"
                          % (init_idx + 1, n_init, inertia))
                if best_inertia is None or inertia < best_inertia:
                    self.cluster_centers_ = cluster_centers
                    self.counts_ = weight_sums
                    best_inertia = inertia

            # Empty context to be used inplace by the convergence check routine
            convergence_context = {}

            # Perform the iterative optimization until the final convergence
            # criterion
            for iteration_idx in range(n_iter):
                # Sample a minibatch from the full dataset
                minibatch_indices = random_state.randint(
                    0, n_samples, self.batch_size)

                # Perform the actual update step on the minibatch data
                batch_inertia, centers_squared_diff = _mini_batch_step(
                    X[minibatch_indices], sample_weight[minibatch_indices],
                    x_squared_norms[minibatch_indices],
                    self.cluster_centers_, self.counts_,
                    old_center_buffer, tol > 0.0, distances=distances,
                    # Here we randomly choose whether to perform
                    # random reassignment: the choice is done as a function
                    # of the iteration index, and the minimum number of
                    # counts, in order to force this reassignment to happen
                    # every once in a while
                    random_reassign=((iteration_idx + 1)
                                     % (10 + int(self.counts_.min())) == 0),
                    random_state=random_state,
                    reassignment_ratio=self.reassignment_ratio,
                    verbose=self.verbose)

                # Monitor convergence and do early stopping if necessary
                if _mini_batch_convergence(
                        self, iteration_idx, n_iter, tol, n_samples,
                        centers_squared_diff, batch_inertia, convergence_context,
                        verbose=self.verbose):
                    break

            self.n_iter_ = iteration_idx + 1

            if self.compute_labels:
                self.labels_, self.inertia_ = \
                        self._labels_inertia_minibatch(X, sample_weight)

            return self
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-67a543a5a282> in <module>
#       1 from sklearn.cluster.k_means_ import check_random_state, check_array, _check_sample_weight, row_norms, _tolerance
# ----> 2 class KmeansClustering(KMeans):
#       3
#       4     def __init__(self, *args, **kwargs):
#       5         super(KmeansClustering, self).__init__(*args, **kwargs)
#
# NameError: name 'KMeans' is not defined

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=20, random_state=0, max_iter=1000, algorithm="elkan", tol=0.000001,n_init=50).fit(features)

# %%
cluster_groupings = {} 

for idx, label in enumerate(kmeans.labels_):
    cluster_groupings[label] = cluster_groupings.get(label, []) + [all_words[idx].text +" " +  str(all_words[idx].box)]

# %%
all_words
# Out:
# [Word(box=Box(xmin=292,ymin=91, xmax=376, ymax=175), text=R&D),
#  Word(box=Box(xmin=341,ymin=201, xmax=418, ymax=211), text=IMPROVEMENT),
#  Word(box=Box(xmin=257,ymin=203, xmax=279, ymax=214), text=R&D),
#  Word(box=Box(xmin=285,ymin=203, xmax=334, ymax=216), text=QUALITY),
#  Word(box=Box(xmin=331,ymin=214, xmax=387, ymax=228), text=SOLUTION),
#  Word(box=Box(xmin=256,ymin=215, xmax=324, ymax=229), text=SUGGESTION/),
#  Word(box=Box(xmin=395,ymin=215, xmax=423, ymax=228), text=FORM),
#  Word(box=Box(xmin=324,ymin=216, xmax=332, ymax=230), text=),
#  Word(box=Box(xmin=560,ymin=264, xmax=575, ymax=279), text=3/),
#  Word(box=Box(xmin=575,ymin=264, xmax=590, ymax=279), text=92),
#  Word(box=Box(xmin=543,ymin=265, xmax=560, ymax=279), text=9/),
#  Word(box=Box(xmin=482,ymin=268, xmax=518, ymax=282), text=Date:),
#  Word(box=Box(xmin=390,ymin=271, xmax=451, ymax=282), text=Martinez),
#  Word(box=Box(xmin=169,ymin=272, xmax=196, ymax=287), text=Ext.),
#  Word(box=Box(xmin=215,ymin=272, xmax=230, ymax=287), text=M.),
#  Word(box=Box(xmin=237,ymin=272, xmax=287, ymax=286), text=Hamann),
#  Word(box=Box(xmin=293,ymin=272, xmax=307, ymax=286), text=P.),
#  Word(box=Box(xmin=370,ymin=272, xmax=384, ymax=285), text=P.),
#  Word(box=Box(xmin=89,ymin=274, xmax=118, ymax=289), text=Name),
#  Word(box=Box(xmin=117,ymin=274, xmax=127, ymax=288), text=/),
#  Word(box=Box(xmin=128,ymin=274, xmax=163, ymax=289), text=Phone),
#  Word(box=Box(xmin=196,ymin=274, xmax=204, ymax=288), text=:),
#  Word(box=Box(xmin=314,ymin=274, xmax=363, ymax=285), text=Harper,),
#  Word(box=Box(xmin=511,ymin=309, xmax=570, ymax=323), text=Licensee),
#  Word(box=Box(xmin=420,ymin=310, xmax=442, ymax=323), text=R&D),
#  Word(box=Box(xmin=448,ymin=310, xmax=491, ymax=323), text=Group:),
#  Word(box=Box(xmin=236,ymin=313, xmax=251, ymax=327), text=J.),
#  Word(box=Box(xmin=256,ymin=313, xmax=273, ymax=326), text=S.),
#  Word(box=Box(xmin=278,ymin=313, xmax=327, ymax=327), text=Wigand),
#  Word(box=Box(xmin=91,ymin=316, xmax=161, ymax=330), text=Supervisor),
#  Word(box=Box(xmin=219,ymin=316, xmax=225, ymax=327), text=:),
#  Word(box=Box(xmin=169,ymin=317, xmax=218, ymax=327), text=Manager),
#  Word(box=Box(xmin=163,ymin=318, xmax=169, ymax=331), text=/),
#  Word(box=Box(xmin=527,ymin=346, xmax=594, ymax=361), text=submitted),
#  Word(box=Box(xmin=464,ymin=348, xmax=520, ymax=362), text=licensee),
#  Word(box=Box(xmin=381,ymin=351, xmax=435, ymax=365), text=analyses),
#  Word(box=Box(xmin=309,ymin=352, xmax=375, ymax=365), text=retention),
#  Word(box=Box(xmin=443,ymin=352, xmax=458, ymax=363), text=on),
#  Word(box=Box(xmin=274,ymin=353, xmax=303, ymax=366), text=coal),
#  Word(box=Box(xmin=95,ymin=355, xmax=169, ymax=370), text=Suggestion:),
#  Word(box=Box(xmin=190,ymin=355, xmax=268, ymax=366), text=Discontinue),
#  Word(box=Box(xmin=536,ymin=363, xmax=549, ymax=374), text=is),
#  Word(box=Box(xmin=554,ymin=363, xmax=578, ymax=374), text=not),
#  Word(box=Box(xmin=318,ymin=365, xmax=352, ymax=379), text=(Note),
#  Word(box=Box(xmin=479,ymin=365, xmax=529, ymax=376), text=testing),
#  Word(box=Box(xmin=373,ymin=366, xmax=402, ymax=376), text=Coal),
#  Word(box=Box(xmin=408,ymin=366, xmax=472, ymax=376), text=Retention),
#  Word(box=Box(xmin=247,ymin=367, xmax=301, ymax=380), text=samples),
#  Word(box=Box(xmin=352,ymin=367, xmax=359, ymax=380), text=:),
#  Word(box=Box(xmin=190,ymin=369, xmax=240, ymax=383), text=product),
#  Word(box=Box(xmin=471,ymin=377, xmax=528, ymax=391), text=physical),
#  Word(box=Box(xmin=401,ymin=378, xmax=437, ymax=389), text=Other),
#  Word(box=Box(xmin=443,ymin=378, xmax=465, ymax=389), text=B&W),
#  Word(box=Box(xmin=318,ymin=380, xmax=386, ymax=391), text=licensees.),
#  Word(box=Box(xmin=261,ymin=381, xmax=275, ymax=394), text=by),
#  Word(box=Box(xmin=190,ymin=383, xmax=256, ymax=394), text=performed),
#  Word(box=Box(xmin=282,ymin=383, xmax=311, ymax=393), text=most),
#  Word(box=Box(xmin=515,ymin=391, xmax=535, ymax=402), text=for),
#  Word(box=Box(xmin=542,ymin=391, xmax=571, ymax=401), text=soft),
#  Word(box=Box(xmin=409,ymin=392, xmax=430, ymax=402), text=and),
#  Word(box=Box(xmin=437,ymin=392, xmax=508, ymax=403), text=inspection),
#  Word(box=Box(xmin=304,ymin=394, xmax=332, ymax=405), text=ends),
#  Word(box=Box(xmin=339,ymin=394, xmax=402, ymax=405), text=stability),
#  Word(box=Box(xmin=282,ymin=397, xmax=297, ymax=405), text=as),
#  Word(box=Box(xmin=191,ymin=398, xmax=275, ymax=406), text=measurements),
#  Word(box=Box(xmin=436,ymin=404, xmax=453, ymax=417), text=be),
#  Word(box=Box(xmin=458,ymin=405, xmax=529, ymax=415), text=sufficient),
#  Word(box=Box(xmin=535,ymin=405, xmax=592, ymax=415), text=measures),
#  Word(box=Box(xmin=360,ymin=406, xmax=410, ymax=419), text=thought),
#  Word(box=Box(xmin=415,ymin=406, xmax=430, ymax=416), text=to),
#  Word(box=Box(xmin=332,ymin=408, xmax=352, ymax=418), text=are),
#  Word(box=Box(xmin=235,ymin=409, xmax=250, ymax=420), text=in),
#  Word(box=Box(xmin=256,ymin=409, xmax=327, ymax=419), text=ciparettes),
#  Word(box=Box(xmin=193,ymin=411, xmax=228, ymax=422), text=spots),
#  Word(box=Box(xmin=478,ymin=416, xmax=500, ymax=429), text=The),
#  Word(box=Box(xmin=395,ymin=418, xmax=463, ymax=431), text=integrity.),
#  Word(box=Box(xmin=506,ymin=418, xmax=566, ymax=431), text=proposed),
#  Word(box=Box(xmin=331,ymin=419, xmax=390, ymax=432), text=physical),
#  Word(box=Box(xmin=261,ymin=420, xmax=325, ymax=434), text=cigarette),
#  Word(box=Box(xmin=214,ymin=423, xmax=255, ymax=431), text=assure),
#  Word(box=Box(xmin=193,ymin=425, xmax=208, ymax=433), text=to),
#  Word(box=Box(xmin=418,ymin=430, xmax=502, ymax=445), text=productivity),
#  Word(box=Box(xmin=508,ymin=430, xmax=514, ymax=444), text=)),
#  Word(box=Box(xmin=339,ymin=433, xmax=410, ymax=446), text=laboratory),
#  Word(box=Box(xmin=503,ymin=433, xmax=507, ymax=444), text=.),
#  Word(box=Box(xmin=277,ymin=434, xmax=333, ymax=445), text=increase),
#  Word(box=Box(xmin=193,ymin=436, xmax=236, ymax=447), text=action),
#  Word(box=Box(xmin=240,ymin=436, xmax=269, ymax=447), text=will),
#  Word(box=Box(xmin=480,ymin=483, xmax=508, ymax=496), text=list),
#  Word(box=Box(xmin=515,ymin=483, xmax=532, ymax=494), text=of),
#  Word(box=Box(xmin=536,ymin=483, xmax=593, ymax=494), text=standard),
#  Word(box=Box(xmin=416,ymin=485, xmax=447, ymax=498), text=from),
#  Word(box=Box(xmin=453,ymin=485, xmax=475, ymax=498), text=the),
#  Word(box=Box(xmin=223,ymin=486, xmax=241, ymax=503), text=(s)),
#  Word(box=Box(xmin=263,ymin=486, xmax=306, ymax=500), text=Delete),
#  Word(box=Box(xmin=313,ymin=486, xmax=341, ymax=499), text=coal),
#  Word(box=Box(xmin=348,ymin=486, xmax=412, ymax=497), text=retention),
#  Word(box=Box(xmin=165,ymin=487, xmax=222, ymax=501), text=Solutions),
#  Word(box=Box(xmin=95,ymin=489, xmax=159, ymax=504), text=Suggested),
#  Word(box=Box(xmin=243,ymin=489, xmax=250, ymax=503), text=:),
#  Word(box=Box(xmin=419,ymin=499, xmax=475, ymax=512), text=licensee),
#  Word(box=Box(xmin=482,ymin=499, xmax=546, ymax=510), text=submitted),
#  Word(box=Box(xmin=264,ymin=501, xmax=320, ymax=514), text=analyses),
#  Word(box=Box(xmin=324,ymin=501, xmax=392, ymax=512), text=performed),
#  Word(box=Box(xmin=397,ymin=501, xmax=412, ymax=511), text=on),
#  Word(box=Box(xmin=538,ymin=510, xmax=566, ymax=523), text=coal),
#  Word(box=Box(xmin=508,ymin=511, xmax=530, ymax=522), text=for),
#  Word(box=Box(xmin=390,ymin=513, xmax=439, ymax=526), text=Special),
#  Word(box=Box(xmin=446,ymin=513, xmax=502, ymax=524), text=requests),
#  Word(box=Box(xmin=320,ymin=514, xmax=374, ymax=528), text=samples.),
#  Word(box=Box(xmin=264,ymin=517, xmax=314, ymax=528), text=product),
#  Word(box=Box(xmin=496,ymin=524, xmax=560, ymax=537), text=submitted),
#  Word(box=Box(xmin=566,ymin=524, xmax=584, ymax=537), text=on),
#  Word(box=Box(xmin=433,ymin=525, xmax=468, ymax=536), text=still),
#  Word(box=Box(xmin=473,ymin=525, xmax=488, ymax=535), text=be),
#  Word(box=Box(xmin=335,ymin=527, xmax=387, ymax=540), text=testing),
#  Word(box=Box(xmin=390,ymin=527, xmax=428, ymax=538), text=could),
#  Word(box=Box(xmin=263,ymin=529, xmax=330, ymax=540), text=retention),
#  Word(box=Box(xmin=286,ymin=539, xmax=350, ymax=553), text=exception),
#  Word(box=Box(xmin=355,ymin=541, xmax=397, ymax=551), text=basis.),
#  Word(box=Box(xmin=264,ymin=543, xmax=281, ymax=553), text=an),
#  Word(box=Box(xmin=545,ymin=603, xmax=563, ymax=617), text=No),
#  Word(box=Box(xmin=461,ymin=605, xmax=483, ymax=619), text=Yes),
#  Word(box=Box(xmin=314,ymin=608, xmax=322, ymax=622), text=),
#  Word(box=Box(xmin=323,ymin=608, xmax=398, ymax=621), text=Supervisor?),
#  Word(box=Box(xmin=264,ymin=609, xmax=314, ymax=622), text=Manager/),
#  Word(box=Box(xmin=229,ymin=610, xmax=260, ymax=623), text=your),
#  Word(box=Box(xmin=96,ymin=612, xmax=127, ymax=623), text=Have),
#  Word(box=Box(xmin=161,ymin=612, xmax=225, ymax=623), text=contacted),
#  Word(box=Box(xmin=131,ymin=613, xmax=156, ymax=624), text=you),
#  Word(box=Box(xmin=497,ymin=644, xmax=547, ymax=657), text=forward),
#  Word(box=Box(xmin=469,ymin=647, xmax=491, ymax=658), text=and),
#  Word(box=Box(xmin=232,ymin=648, xmax=288, ymax=662), text=Manager,),
#  Word(box=Box(xmin=344,ymin=648, xmax=394, ymax=662), text=contact),
#  Word(box=Box(xmin=401,ymin=648, xmax=464, ymax=661), text=suggester),
#  Word(box=Box(xmin=296,ymin=649, xmax=338, ymax=662), text=please),
#  Word(box=Box(xmin=154,ymin=651, xmax=211, ymax=664), text=Comments:),
#  Word(box=Box(xmin=211,ymin=651, xmax=217, ymax=662), text=),
#  Word(box=Box(xmin=98,ymin=654, xmax=150, ymax=665), text=Manager),
#  Word(box=Box(xmin=267,ymin=662, xmax=323, ymax=676), text=Council.),
#  Word(box=Box(xmin=211,ymin=663, xmax=261, ymax=676), text=Quality),
#  Word(box=Box(xmin=162,ymin=665, xmax=177, ymax=676), text=to),
#  Word(box=Box(xmin=183,ymin=665, xmax=205, ymax=675), text=the),
#  Word(box=Box(xmin=99,ymin=666, xmax=155, ymax=677), text=comments),
#  Word(box=Box(xmin=130,ymin=823, xmax=145, ymax=837), text=wp),
#  Word(box=Box(xmin=102,ymin=824, xmax=123, ymax=837), text=qip),
#  Word(box=Box(xmin=124,ymin=824, xmax=130, ymax=838), text=.),
#  Word(box=Box(xmin=525,ymin=904, xmax=641, ymax=926), text=597005708)]

# %%
cluster_groupings
# Out:
# {18: ['R&D Box(xmin=292,ymin=91, xmax=376, ymax=175)',
#   'IMPROVEMENT Box(xmin=341,ymin=201, xmax=418, ymax=211)',
#   'R&D Box(xmin=257,ymin=203, xmax=279, ymax=214)',
#   'QUALITY Box(xmin=285,ymin=203, xmax=334, ymax=216)',
#   'SOLUTION Box(xmin=331,ymin=214, xmax=387, ymax=228)',
#   'SUGGESTION/ Box(xmin=256,ymin=215, xmax=324, ymax=229)',
#   'FORM Box(xmin=395,ymin=215, xmax=423, ymax=228)',
#   ' Box(xmin=324,ymin=216, xmax=332, ymax=230)'],
#  7: ['3/ Box(xmin=560,ymin=264, xmax=575, ymax=279)',
#   '92 Box(xmin=575,ymin=264, xmax=590, ymax=279)',
#   '9/ Box(xmin=543,ymin=265, xmax=560, ymax=279)',
#   'Date: Box(xmin=482,ymin=268, xmax=518, ymax=282)',
#   'Licensee Box(xmin=511,ymin=309, xmax=570, ymax=323)'],
#  1: ['Martinez Box(xmin=390,ymin=271, xmax=451, ymax=282)',
#   'P. Box(xmin=293,ymin=272, xmax=307, ymax=286)',
#   'P. Box(xmin=370,ymin=272, xmax=384, ymax=285)',
#   'Harper, Box(xmin=314,ymin=274, xmax=363, ymax=285)',
#   'Wigand Box(xmin=278,ymin=313, xmax=327, ymax=327)'],
#  5: ['Ext. Box(xmin=169,ymin=272, xmax=196, ymax=287)',
#   'M. Box(xmin=215,ymin=272, xmax=230, ymax=287)',
#   'Hamann Box(xmin=237,ymin=272, xmax=287, ymax=286)',
#   ': Box(xmin=196,ymin=274, xmax=204, ymax=288)',
#   'J. Box(xmin=236,ymin=313, xmax=251, ymax=327)',
#   'S. Box(xmin=256,ymin=313, xmax=273, ymax=326)',
#   ': Box(xmin=219,ymin=316, xmax=225, ymax=327)',
#   'Manager Box(xmin=169,ymin=317, xmax=218, ymax=327)'],
#  19: ['Name Box(xmin=89,ymin=274, xmax=118, ymax=289)',
#   '/ Box(xmin=117,ymin=274, xmax=127, ymax=288)',
#   'Phone Box(xmin=128,ymin=274, xmax=163, ymax=289)',
#   'Supervisor Box(xmin=91,ymin=316, xmax=161, ymax=330)',
#   '/ Box(xmin=163,ymin=318, xmax=169, ymax=331)',
#   'Suggestion: Box(xmin=95,ymin=355, xmax=169, ymax=370)'],
#  4: ['R&D Box(xmin=420,ymin=310, xmax=442, ymax=323)',
#   'Group: Box(xmin=448,ymin=310, xmax=491, ymax=323)',
#   'analyses Box(xmin=381,ymin=351, xmax=435, ymax=365)',
#   'on Box(xmin=443,ymin=352, xmax=458, ymax=363)',
#   'Retention Box(xmin=408,ymin=366, xmax=472, ymax=376)',
#   'Other Box(xmin=401,ymin=378, xmax=437, ymax=389)',
#   'B&W Box(xmin=443,ymin=378, xmax=465, ymax=389)',
#   'and Box(xmin=409,ymin=392, xmax=430, ymax=402)',
#   'inspection Box(xmin=437,ymin=392, xmax=508, ymax=403)',
#   'be Box(xmin=436,ymin=404, xmax=453, ymax=417)',
#   'to Box(xmin=415,ymin=406, xmax=430, ymax=416)',
#   'integrity. Box(xmin=395,ymin=418, xmax=463, ymax=431)',
#   'productivity Box(xmin=418,ymin=430, xmax=502, ymax=445)'],
#  8: ['submitted Box(xmin=527,ymin=346, xmax=594, ymax=361)',
#   'licensee Box(xmin=464,ymin=348, xmax=520, ymax=362)',
#   'is Box(xmin=536,ymin=363, xmax=549, ymax=374)',
#   'not Box(xmin=554,ymin=363, xmax=578, ymax=374)',
#   'testing Box(xmin=479,ymin=365, xmax=529, ymax=376)',
#   'physical Box(xmin=471,ymin=377, xmax=528, ymax=391)',
#   'for Box(xmin=515,ymin=391, xmax=535, ymax=402)',
#   'soft Box(xmin=542,ymin=391, xmax=571, ymax=401)',
#   'sufficient Box(xmin=458,ymin=405, xmax=529, ymax=415)',
#   'measures Box(xmin=535,ymin=405, xmax=592, ymax=415)',
#   'The Box(xmin=478,ymin=416, xmax=500, ymax=429)',
#   'proposed Box(xmin=506,ymin=418, xmax=566, ymax=431)',
#   ') Box(xmin=508,ymin=430, xmax=514, ymax=444)',
#   '. Box(xmin=503,ymin=433, xmax=507, ymax=444)'],
#  17: ['retention Box(xmin=309,ymin=352, xmax=375, ymax=365)',
#   '(Note Box(xmin=318,ymin=365, xmax=352, ymax=379)',
#   'Coal Box(xmin=373,ymin=366, xmax=402, ymax=376)',
#   ': Box(xmin=352,ymin=367, xmax=359, ymax=380)',
#   'licensees. Box(xmin=318,ymin=380, xmax=386, ymax=391)',
#   'stability Box(xmin=339,ymin=394, xmax=402, ymax=405)',
#   'thought Box(xmin=360,ymin=406, xmax=410, ymax=419)',
#   'are Box(xmin=332,ymin=408, xmax=352, ymax=418)',
#   'physical Box(xmin=331,ymin=419, xmax=390, ymax=432)',
#   'laboratory Box(xmin=339,ymin=433, xmax=410, ymax=446)'],
#  15: ['coal Box(xmin=274,ymin=353, xmax=303, ymax=366)',
#   'samples Box(xmin=247,ymin=367, xmax=301, ymax=380)',
#   'by Box(xmin=261,ymin=381, xmax=275, ymax=394)',
#   'most Box(xmin=282,ymin=383, xmax=311, ymax=393)',
#   'ends Box(xmin=304,ymin=394, xmax=332, ymax=405)',
#   'as Box(xmin=282,ymin=397, xmax=297, ymax=405)',
#   'ciparettes Box(xmin=256,ymin=409, xmax=327, ymax=419)',
#   'cigarette Box(xmin=261,ymin=420, xmax=325, ymax=434)',
#   'increase Box(xmin=277,ymin=434, xmax=333, ymax=445)'],
#  9: ['Discontinue Box(xmin=190,ymin=355, xmax=268, ymax=366)',
#   'product Box(xmin=190,ymin=369, xmax=240, ymax=383)',
#   'performed Box(xmin=190,ymin=383, xmax=256, ymax=394)',
#   'measurements Box(xmin=191,ymin=398, xmax=275, ymax=406)',
#   'in Box(xmin=235,ymin=409, xmax=250, ymax=420)',
#   'spots Box(xmin=193,ymin=411, xmax=228, ymax=422)',
#   'assure Box(xmin=214,ymin=423, xmax=255, ymax=431)',
#   'to Box(xmin=193,ymin=425, xmax=208, ymax=433)',
#   'action Box(xmin=193,ymin=436, xmax=236, ymax=447)',
#   'will Box(xmin=240,ymin=436, xmax=269, ymax=447)'],
#  13: ['list Box(xmin=480,ymin=483, xmax=508, ymax=496)',
#   'of Box(xmin=515,ymin=483, xmax=532, ymax=494)',
#   'standard Box(xmin=536,ymin=483, xmax=593, ymax=494)',
#   'submitted Box(xmin=482,ymin=499, xmax=546, ymax=510)',
#   'coal Box(xmin=538,ymin=510, xmax=566, ymax=523)',
#   'for Box(xmin=508,ymin=511, xmax=530, ymax=522)',
#   'submitted Box(xmin=496,ymin=524, xmax=560, ymax=537)',
#   'on Box(xmin=566,ymin=524, xmax=584, ymax=537)'],
#  0: ['from Box(xmin=416,ymin=485, xmax=447, ymax=498)',
#   'the Box(xmin=453,ymin=485, xmax=475, ymax=498)',
#   'retention Box(xmin=348,ymin=486, xmax=412, ymax=497)',
#   'licensee Box(xmin=419,ymin=499, xmax=475, ymax=512)',
#   'on Box(xmin=397,ymin=501, xmax=412, ymax=511)',
#   'Special Box(xmin=390,ymin=513, xmax=439, ymax=526)',
#   'requests Box(xmin=446,ymin=513, xmax=502, ymax=524)',
#   'still Box(xmin=433,ymin=525, xmax=468, ymax=536)',
#   'be Box(xmin=473,ymin=525, xmax=488, ymax=535)',
#   'could Box(xmin=390,ymin=527, xmax=428, ymax=538)'],
#  2: ['(s) Box(xmin=223,ymin=486, xmax=241, ymax=503)',
#   'Solutions Box(xmin=165,ymin=487, xmax=222, ymax=501)',
#   'Suggested Box(xmin=95,ymin=489, xmax=159, ymax=504)',
#   ': Box(xmin=243,ymin=489, xmax=250, ymax=503)'],
#  16: ['Delete Box(xmin=263,ymin=486, xmax=306, ymax=500)',
#   'coal Box(xmin=313,ymin=486, xmax=341, ymax=499)',
#   'analyses Box(xmin=264,ymin=501, xmax=320, ymax=514)',
#   'performed Box(xmin=324,ymin=501, xmax=392, ymax=512)',
#   'samples. Box(xmin=320,ymin=514, xmax=374, ymax=528)',
#   'product Box(xmin=264,ymin=517, xmax=314, ymax=528)',
#   'testing Box(xmin=335,ymin=527, xmax=387, ymax=540)',
#   'retention Box(xmin=263,ymin=529, xmax=330, ymax=540)',
#   'exception Box(xmin=286,ymin=539, xmax=350, ymax=553)',
#   'basis. Box(xmin=355,ymin=541, xmax=397, ymax=551)',
#   'an Box(xmin=264,ymin=543, xmax=281, ymax=553)'],
#  6: ['No Box(xmin=545,ymin=603, xmax=563, ymax=617)',
#   'Yes Box(xmin=461,ymin=605, xmax=483, ymax=619)',
#   'forward Box(xmin=497,ymin=644, xmax=547, ymax=657)',
#   'and Box(xmin=469,ymin=647, xmax=491, ymax=658)',
#   'suggester Box(xmin=401,ymin=648, xmax=464, ymax=661)'],
#  10: [' Box(xmin=314,ymin=608, xmax=322, ymax=622)',
#   'Supervisor? Box(xmin=323,ymin=608, xmax=398, ymax=621)',
#   'Manager/ Box(xmin=264,ymin=609, xmax=314, ymax=622)',
#   'contact Box(xmin=344,ymin=648, xmax=394, ymax=662)',
#   'please Box(xmin=296,ymin=649, xmax=338, ymax=662)',
#   'Council. Box(xmin=267,ymin=662, xmax=323, ymax=676)'],
#  14: ['your Box(xmin=229,ymin=610, xmax=260, ymax=623)',
#   'contacted Box(xmin=161,ymin=612, xmax=225, ymax=623)',
#   'Manager, Box(xmin=232,ymin=648, xmax=288, ymax=662)',
#   'Comments: Box(xmin=154,ymin=651, xmax=211, ymax=664)',
#   ' Box(xmin=211,ymin=651, xmax=217, ymax=662)',
#   'Quality Box(xmin=211,ymin=663, xmax=261, ymax=676)',
#   'to Box(xmin=162,ymin=665, xmax=177, ymax=676)',
#   'the Box(xmin=183,ymin=665, xmax=205, ymax=675)'],
#  3: ['Have Box(xmin=96,ymin=612, xmax=127, ymax=623)',
#   'you Box(xmin=131,ymin=613, xmax=156, ymax=624)',
#   'Manager Box(xmin=98,ymin=654, xmax=150, ymax=665)',
#   'comments Box(xmin=99,ymin=666, xmax=155, ymax=677)'],
#  11: ['wp Box(xmin=130,ymin=823, xmax=145, ymax=837)',
#   'qip Box(xmin=102,ymin=824, xmax=123, ymax=837)',
#   '. Box(xmin=124,ymin=824, xmax=130, ymax=838)'],
#  12: ['597005708 Box(xmin=525,ymin=904, xmax=641, ymax=926)']}

# %%
def label_to_color(label):
    return {
        "question": Constants.RED,
        "answer": Constants.GREEN,
        "header": Constants.BLUE,
        "other": Constants.CYAN,
    }[label]
    
    
def color_image(image, annotation):
    for entity in annotation.entities:
        box = entity.box
        image_crop = image[box.ymin:box.ymax, 
                           box.xmin:box.xmax, :]
        image_crop[np.where((image_crop < [127,127,127]).all(axis = 2))] = label_to_color(entity.label)
        image[box.ymin:box.ymax, 
                          box.xmin:box.xmax, :] = image_crop
        
    return image

# %%
colored_images = {image_file:color_image(cv2.imread(os.path.join(train_images_dir, image_file)), annotations[idx]) 
                for idx, image_file in enumerate(train_image_file_names) }
